# %% [markdown]
# # ML & Modeling II Lab Notebook

# %% [markdown]
# # Predicting Success in Data 100
#
# Imagine you're working with the course staff for Data 100 at UC Berkeley.
#
# Your goal is to build a model that predicts whether a student will pass the course based on features like study habits, attendance, and performance.
#
# You will explore different models and compare their performance.
#
# Beginner students should complete Part 1.
#
# Accelerated students should complete both Part 1 and Part 2.

# %% [markdown]
# ## Setup
# Run the cell below to import all necessary libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Create the Dataset
#
# We will simulate student data to train our models.

# %%
student_features, passed = make_classification(
    n_samples=500,
    n_features=5,
    n_informative=3,
    n_redundant=0,
    random_state=42
)

X_train, X_test, y_train, y_test = train_test_split(
    student_features, passed, test_size=0.2, random_state=42
)

# %% [markdown]
# # Part 1: Beginner
#
# Complete Questions 1–5.

# %% [markdown]
# ## Question 1: Train a Decision Tree
#
# Train a Decision Tree model to predict whether a student passes.
#
# Fill in the blanks below.

# %%
tree = DecisionTreeClassifier(max_depth=____)
tree.fit(____, ____)

y_pred_tree = tree.predict(____)

# %% [markdown]
# ## Question 2: Evaluate the Decision Tree
#
# Compute the accuracy of your model.

# %%
acc_tree = accuracy_score(____, ____)
print("Decision Tree Accuracy:", acc_tree)

# %% [markdown]
# ## Question 3: Short Answer
#
# What happens when max_depth is very large?
#
# In the context of Data 100:
# - What would an overfit model look like?
# - Why might it perform poorly on new students?

# %% [markdown]
# (Write your answer here)

# %% [markdown]
# ## Question 4: Train a Random Forest
#
# Now train a Random Forest model.
#
# Fill in the blanks below.

# %%
rf = RandomForestClassifier(
    n_estimators=____,
    max_depth=____,
    random_state=42
)

rf.fit(____, ____)

y_pred_rf = rf.predict(____)

# %% [markdown]
# ## Question 5: Compare Models
#
# Compute the accuracy of the Random Forest and compare it to the Decision Tree.
#
# Which performs better?

# %%
acc_rf = accuracy_score(y_test, y_pred_rf)

print("Decision Tree:", acc_tree)
print("Random Forest:", acc_rf)

# %% [markdown]
# Short Answer:
#
# Why might Random Forest perform better than a single Decision Tree?
#
# In this context, what does each tree represent?

# %% [markdown]
# (Write your answer here)

# %% [markdown]
# # Part 2: Advanced (Accelerated Students)
#
# Complete Questions 6–7.

# %% [markdown]
# ## Question 6: Gradient Boosting
#
# Train a Gradient Boosting model.
#
# Fill in the blanks below.

# %%
gb = GradientBoostingClassifier(
    n_estimators=____,
    learning_rate=____,
    max_depth=____
)

gb.fit(____, ____)

y_pred_gb = gb.predict(____)

# %% [markdown]
# ## Question 7: Final Comparison and Reflection
#
# Compute the accuracy of Gradient Boosting and compare all models.

# %%
acc_gb = accuracy_score(y_test, y_pred_gb)

print("Decision Tree:", acc_tree)
print("Random Forest:", acc_rf)
print("Gradient Boosting:", acc_gb)

# %% [markdown]
# Short Answer:
#
# 1. Which model performed best?
# 2. How is Gradient Boosting different from Random Forest?
# 3. What does it mean for a model to "focus on mistakes" in this setting?
# 4. If you were Data 100 staff, which model would you deploy and why?

# %% [markdown]
# (Write your answers here)

# %% [markdown]
# ## End of Lab
#
# You built and compared multiple models for predicting student success in Data 100.
#
# Think about:
# - How model complexity affects performance
# - The tradeoff between interpretability and accuracy
# - When you would use each model in practice
#
# These ideas will come up repeatedly in real-world machine learning.
